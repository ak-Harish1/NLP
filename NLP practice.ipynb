# %% [markdown]
# <a href="https://colab.research.google.com/github/ak-Harish1/NLP/blob/main/NLP%20practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> l
#
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] bcp47............... BCP-47 Language Tags
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
# ...

# %%
nltk.download('punkt') # tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
para = """Dustin Poirier, known as "The Diamond," is an American professional mixed martial artist competing in the UFC lightweight division.
He has had a remarkable career with significant achievements and memorable fights
As of the most recent fights, Poirier continues to compete at a high level, showcasing his skills and determination.
His career trajectory and personal growth indicate a fighter who is committed to his craft and always ready for new challenges.
"""

# %%
# sentence segmentation
sen = nltk.sent_tokenize(para)
sen
# Out:
# ['Dustin Poirier, known as "The Diamond," is an American professional mixed martial artist competing in the UFC lightweight division.',
#  'He has had a remarkable career with significant achievements and memorable fights\nAs of the most recent fights, Poirier continues to compete at a high level, showcasing his skills and determination.',
#  'His career trajectory and personal growth indicate a fighter who is committed to his craft and always ready for new challenges.']

# %%
# word segmentation
word = nltk.word_tokenize(para)
word
# Out:
# ['Dustin',
#  'Poirier',
#  ',',
#  'known',
#  'as',
#  '``',
#  'The',
#  'Diamond',
#  ',',
#  "''",
#  'is',
#  'an',
#  'American',
#  'professional',
#  'mixed',
#  'martial',
#  'artist',
#  'competing',
#  'in',
#  'the',
#  'UFC',
#  'lightweight',
#  'division',
#  '.',
#  'He',
#  'has',
#  'had',
#  'a',
#  'remarkable',
#  'career',
#  'with',
#  'significant',
#  'achievements',
#  'and',
#  'memorable',
#  'fights',
#  'As',
#  'of',
#  'the',
#  'most',
#  'recent',
#  'fights',
#  ',',
#  'Poirier',
#  'continues',
#  'to',
#  'compete',
#  'at',
#  'a',
#  'high',
#  'level',
#  ',',
#  'showcasing',
#  'his',
#  'skills',
#  'and',
#  'determination',
#  '.',
#  'His',
#  'career',
#  'trajectory',
#  'and',
#  'personal',
#  'growth',
#  'indicate',
#  'a',
#  'fighter',
#  'who',
#  'is',
#  'committed',
#  'to',
#  'his',
#  'craft',
#  'and',
#  'always',
#  'ready',
#  'for',
#  'new',
#  'challenges',
#  '.']

# %%
# stop words - is are the etc..
from nltk.stem import PorterStemmer
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
new_wordprep = new_words
Stemmer = PorterStemmer()

# %%
from nltk.corpus import stopwords
#List stopwords
stopwords = set(stopwords.words('english'))

# %%
new_words=[]
for w in words_no_punc:
  if w not in stopwords:
    new_words.append(w)
print(new_words)
# Out:
# ['dustin', 'poirier', 'known', 'diamond', 'american', 'professional', 'mixed', 'martial', 'artist', 'competing', 'ufc', 'lightweight', 'division', 'remarkable', 'career', 'significant', 'achievements', 'memorable', 'fights', 'recent', 'fights', 'poirier', 'continues', 'compete', 'high', 'level', 'showcasing', 'skills', 'determination', 'career', 'trajectory', 'personal', 'growth', 'indicate', 'fighter', 'committed', 'craft', 'always', 'ready', 'new', 'challenges']

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# for i in range(len(sen)):
#   words = nltk.sent_tokenize(sen[i])
#   words = [lemmatizer.lemmatize(word) for word in words if word not in set(stopwords.words('english'))]
#   sen[i] = ' '.join(words)

# %%
from nltk.tokenize import TreebankWordTokenizer
from nltk.tokenize import WordPunctTokenizer
from nltk.tokenize import RegexpTokenizer

# %%
tbank = TreebankWordTokenizer()
tbank.tokenize(para)
# Out:
# ['Dustin',
#  'Poirier',
#  ',',
#  'known',
#  'as',
#  '``',
#  'The',
#  'Diamond',
#  ',',
#  "''",
#  'is',
#  'an',
#  'American',
#  'professional',
#  'mixed',
#  'martial',
#  'artist',
#  'competing',
#  'in',
#  'the',
#  'UFC',
#  'lightweight',
#  'division.',
#  'He',
#  'has',
#  'had',
#  'a',
#  'remarkable',
#  'career',
#  'with',
#  'significant',
#  'achievements',
#  'and',
#  'memorable',
#  'fights',
#  'As',
#  'of',
#  'the',
#  'most',
#  'recent',
#  'fights',
#  ',',
#  'Poirier',
#  'continues',
#  'to',
#  'compete',
#  'at',
#  'a',
#  'high',
#  'level',
#  ',',
#  'showcasing',
#  'his',
#  'skills',
#  'and',
#  'determination.',
#  'His',
#  'career',
#  'trajectory',
#  'and',
#  'personal',
#  'growth',
#  'indicate',
#  'a',
#  'fighter',
#  'who',
#  'is',
#  'committed',
#  'to',
#  'his',
#  'craft',
#  'and',
#  'always',
#  'ready',
#  'for',
#  'new',
#  'challenges',
#  '.']

# %%
wpunct = WordPunctTokenizer()
wpunct.tokenize(para)
# Out:
# ['Dustin',
#  'Poirier',
#  ',',
#  'known',
#  'as',
#  '"',
#  'The',
#  'Diamond',
#  ',"',
#  'is',
#  'an',
#  'American',
#  'professional',
#  'mixed',
#  'martial',
#  'artist',
#  'competing',
#  'in',
#  'the',
#  'UFC',
#  'lightweight',
#  'division',
#  '.',
#  'He',
#  'has',
#  'had',
#  'a',
#  'remarkable',
#  'career',
#  'with',
#  'significant',
#  'achievements',
#  'and',
#  'memorable',
#  'fights',
#  'As',
#  'of',
#  'the',
#  'most',
#  'recent',
#  'fights',
#  ',',
#  'Poirier',
#  'continues',
#  'to',
#  'compete',
#  'at',
#  'a',
#  'high',
#  'level',
#  ',',
#  'showcasing',
#  'his',
#  'skills',
#  'and',
#  'determination',
#  '.',
#  'His',
#  'career',
#  'trajectory',
#  'and',
#  'personal',
#  'growth',
#  'indicate',
#  'a',
#  'fighter',
#  'who',
#  'is',
#  'committed',
#  'to',
#  'his',
#  'craft',
#  'and',
#  'always',
#  'ready',
#  'for',
#  'new',
#  'challenges',
#  '.']

# %%
regexp = RegexpTokenizer(r'\w+')
regexp.tokenize(para)
# Out:
# ['Dustin',
#  'Poirier',
#  'known',
#  'as',
#  'The',
#  'Diamond',
#  'is',
#  'an',
#  'American',
#  'professional',
#  'mixed',
#  'martial',
#  'artist',
#  'competing',
#  'in',
#  'the',
#  'UFC',
#  'lightweight',
#  'division',
#  'He',
#  'has',
#  'had',
#  'a',
#  'remarkable',
#  'career',
#  'with',
#  'significant',
#  'achievements',
#  'and',
#  'memorable',
#  'fights',
#  'As',
#  'of',
#  'the',
#  'most',
#  'recent',
#  'fights',
#  'Poirier',
#  'continues',
#  'to',
#  'compete',
#  'at',
#  'a',
#  'high',
#  'level',
#  'showcasing',
#  'his',
#  'skills',
#  'and',
#  'determination',
#  'His',
#  'career',
#  'trajectory',
#  'and',
#  'personal',
#  'growth',
#  'indicate',
#  'a',
#  'fighter',
#  'who',
#  'is',
#  'committed',
#  'to',
#  'his',
#  'craft',
#  'and',
#  'always',
#  'ready',
#  'for',
#  'new',
#  'challenges']

# %%
from nltk.probability import FreqDist
fd = FreqDist(new_words)
fd.most_common(5)
# Out:
# [('poirier', 2), ('career', 2), ('fights', 2), ('dustin', 1), ('known', 1)]

# %%
# import matplotlib.pyplot as plt

fd.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wc = WordCloud().generate_from_frequencies(fd)
plt.figure(figsize = (8,8))
plt.imshow(wc)

# %%
from wordcloud import WordCloud

# Create a word cloud object
wc = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(fd)

# Display the word cloud
plt.figure(figsize=(8, 8))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
cloud = WordCloud()
cloud = cloud.generate(para)

# %%
import numpy as np
from PIL import Image
mask1 = np.array(Image.open("/content/drive/MyDrive/Colab Notebooks/NLP/bg.jpg"))
c1 = WordCloud(background_color = 'white',max_words=100,mask = mask1, contour_width = 1)
c1.generate(para)
plt.imshow(c1,interpolation='none')
plt.axis('off')
plt.show()

# %%
mask1 = np.array(Image.open("/content/drive/MyDrive/Colab Notebooks/NLP/g.jpg"))
c1 = WordCloud(background_color = 'white',max_words=200,mask = mask1,contour_width = 1)
c1.generate(para)
plt.imshow(c1,interpolation='none')
plt.axis('off')
plt.show()

# %%
mask1 = np.array(Image.open("/content/drive/MyDrive/Colab Notebooks/NLP/appl.png"))
c1 = WordCloud(background_color = 'white',max_words=200,mask = mask1,contour_width = 2)
c1.generate(para)
plt.imshow(c1,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# POS
nltk.download("averaged_perceptron_tagger")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
pos = nltk.pos_tag(word)
pos
# Out:
# [('Dustin', 'NNP'),
#  ('Poirier', 'NNP'),
#  (',', ','),
#  ('known', 'VBN'),
#  ('as', 'IN'),
#  ('``', '``'),
#  ('The', 'DT'),
#  ('Diamond', 'NNP'),
#  (',', ','),
#  ("''", "''"),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('American', 'JJ'),
#  ('professional', 'NN'),
#  ('mixed', 'JJ'),
#  ('martial', 'JJ'),
#  ('artist', 'NN'),
#  ('competing', 'VBG'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('UFC', 'NNP'),
#  ('lightweight', 'JJ'),
#  ('division', 'NN'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('has', 'VBZ'),
#  ('had', 'VBD'),
#  ('a', 'DT'),
#  ('remarkable', 'JJ'),
#  ('career', 'NN'),
#  ('with', 'IN'),
#  ('significant', 'JJ'),
#  ('achievements', 'NNS'),
#  ('and', 'CC'),
#  ('memorable', 'JJ'),
#  ('fights', 'NNS'),
#  ('As', 'IN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('recent', 'JJ'),
#  ('fights', 'NNS'),
#  (',', ','),
#  ('Poirier', 'NNP'),
#  ('continues', 'VBZ'),
#  ('to', 'TO'),
#  ('compete', 'VB'),
#  ('at', 'IN'),
#  ('a', 'DT'),
# ...
